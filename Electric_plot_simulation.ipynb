# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from copy import deepcopy
import os
import imageio

def makefield(xs, ys):
    qtopos = {1: (-1,0), -1: (1,0)}
    n = len(xs)    
    Exs = [[0. for k in range(n)] for j in range(n)]
    Eys = deepcopy(Exs)
    for j,x in enumerate(xs):
        for k,y in enumerate(ys):
            for q,pos in qtopos.items():
                posx, posy = pos
                R = sqrt((x - posx)**2 + (y - posy)**2)
                Exs[k][j] += q*(x - posx)/R**3
                Eys[k][j] += q*(y - posy)/R**3
  
    return Exs, Eys

# %%
def plotfield(boxl,n):
    xs = [-boxl + i*2*boxl/(n-1) for i in range(n)]
    ys = xs
    Exs, Eys = makefield(xs, ys)
    xs=np.array(xs) ;    ys=np.array(ys)
    Exs=np.array(Exs);    Eys=np.array(Eys)
    plt.streamplot(xs, ys, Exs, Eys,color='g')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig('field1.png')
    plt.show()
    
plotfield(2.,20)

# %%
def plotfield(boxl,n):
    xs = [-boxl + i*2*boxl/(n-1) for i in range(n)]
    ys = xs
    Exs, Eys = makefield(xs, ys)
    xs=np.array(xs) ;    ys=np.array(ys)
    Exs=np.array(Exs);    Eys=np.array(Eys)
    plt.streamplot(xs, ys, Exs, Eys,color='m')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig('field2.png')
    plt.show()
    
plotfield(2.,60)

# %%
def plotfield(boxl,n):
    xs = [-boxl + i*2*boxl/(n-1) for i in range(n)]
    ys = xs
    Exs, Eys = makefield(xs, ys)
    xs=np.array(xs) ;    ys=np.array(ys)
    Exs=np.array(Exs);    Eys=np.array(Eys)
    plt.streamplot(xs, ys, Exs, Eys)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig('field3.png')
    plt.show()
    
plotfield(2.,100)

# %%
def plotfield(boxl,n):
    xs = [-boxl + i*2*boxl/(n-1) for i in range(n)]
    ys = xs
    Exs, Eys = makefield(xs, ys)
    xs=np.array(xs) ;    ys=np.array(ys)
    Exs=np.array(Exs);    Eys=np.array(Eys)
    plt.streamplot(xs, ys, Exs, Eys,color='r')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig('field4.png')
    plt.show()
    
plotfield(4.,20)

# %%
def plotfield(boxl,n):
    xs = [-boxl + i*2*boxl/(n-1) for i in range(n)]
    ys = xs
    Exs, Eys = makefield(xs, ys)
    xs=np.array(xs) ;    ys=np.array(ys)
    Exs=np.array(Exs);    Eys=np.array(Eys)
    plt.streamplot(xs, ys, Exs, Eys, color='b')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig('field5.png')
    plt.show()
    
plotfield(4.,60)

# %%
def plotfield(boxl,n):
    xs = [-boxl + i*2*boxl/(n-1) for i in range(n)]
    ys = xs
    Exs, Eys = makefield(xs, ys)
    xs=np.array(xs) ;    ys=np.array(ys)
    Exs=np.array(Exs);    Eys=np.array(Eys)
    plt.streamplot(xs, ys, Exs, Eys,color='y')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig('field6.png')
    plt.show()
    
plotfield(4.,100)

# %%
with imageio.get_writer('ElectricField_plotlines.gif', mode='I') as writer:
    for filename in ['field1.png', 'field2.png', 'field3.png','field4.png','field5.png','field6.png']:
        image = imageio.v2.imread(filename)
        writer.append_data(image)
